# %% [markdown]
# # Odev 2

# %% [markdown]
# ### Ön Çalışma

# %%
"""
import numpy as np

x = np.zeros(20)
y = np.zeros(20)

y[-1] = 0
x[-1] = 0
x[0] = 1
x[1] = -1
  
for n in range(0, 4):
  y[n] = -0.5*y[n-1]+x[n]+2*x[n-1]
  
print(y[0:4])


from scipy import signal

x = np.array([1, -1, 0, 0], dtype = float)
b = [1, 2]
a = [1, 0.5]
y = signal.lfilter(b, a, x)
print(y)


from matplotlib import pyplot as plt

n = np.arange(0, 4)
plt.stem(n, y)
plt.title("y[n]")
plt.xlabel("n")

import numpy as np
x=np.array([1,2,-1],dtype=float)
h=np.array([1,3],dtype=float)

nXmin = 0
nHmin = 0

M = len(x)
N = len(h)
L = M + N -1
y=np.zeros(L)

for n in range(L): 
    y[n]=0
    for k in range(M):
        if (n-k)>=0 and (n-k)<N:
            y[n]=y[n]+x[k]*h[n-k]
print(y)

nY = [i for i in range(nXmin+nHmin,nXmin+nHmin+L)]
print(nY) 

x=np.array([1, 0, 2,-1],dtype=float)
h=np.array([1, 0, 0, 0, 3],dtype=float)

nXmin = -1
nHmin = -2

M = len(x)
N = len(h)
L = M + N -1
y=np.zeros(L)

for n in range(L): 
    y[n]=0
    for k in range(M):
        if (n-k)>=0 and (n-k)<N:
            y[n]=y[n]+x[k]*h[n-k]
print(y)

nY = [i for i in range(nXmin+nHmin,nXmin+nHmin+L)]
print(nY) 

import matplotlib.pyplot as plt
plt.stem(nY,y)
plt.title('y[n]')

import numpy as np
from scipy import signal

x = np.array([1, 2, -1], dtype = float)
h = np.array([1, 3], dtype = float)

print(np.convolve(x, h))
print(signal.convolve(x, h))
"""
# Out:
# '\nimport numpy as np\n\nx = np.zeros(20)\ny = np.zeros(20)\n\ny[-1] = 0\nx[-1] = 0\nx[0] = 1\nx[1] = -1\n  \nfor n in range(0, 4):\n  y[n] = -0.5*y[n-1]+x[n]+2*x[n-1]\n  \nprint(y[0:4])\n\n\nfrom scipy import signal\n\nx = np.array([1, -1, 0, 0], dtype = float)\nb = [1, 2]\na = [1, 0.5]\ny = signal.lfilter(b, a, x)\nprint(y)\n\n\nfrom matplotlib import pyplot as plt\n\nn = np.arange(0, 4)\nplt.stem(n, y)\nplt.title("y[n]")\nplt.xlabel("n")\n\nimport numpy as np\nx=np.array([1,2,-1],dtype=float)\nh=np.array([1,3],dtype=float)\n\nnXmin = 0\nnHmin = 0\n\nM = len(x)\nN = len(h)\nL = M + N -1\ny=np.zeros(L)\n\nfor n in range(L): \n    y[n]=0\n    for k in range(M):\n        if (n-k)>=0 and (n-k)<N:\n            y[n]=y[n]+x[k]*h[n-k]\nprint(y)\n\nnY = [i for i in range(nXmin+nHmin,nXmin+nHmin+L)]\nprint(nY) \n\nx=np.array([1, 0, 2,-1],dtype=float)\nh=np.array([1, 0, 0, 0, 3],dtype=float)\n\nnXmin = -1\nnHmin = -2\n\nM = len(x)\nN = len(h)\nL = M + N -1\ny=np.zeros(L)\n\nfor n in range(L):
# ...

# %% [markdown]
# ## Soru-1  𝑦[𝑛] − 1.2𝑦[𝑛 − 1] = 𝑥[𝑛] − 𝑥[𝑛 − 4] dürtü cevabı nedir ?

# %% [markdown]
# ##### y[n] = x[n] - x[n-4] + 1.2y[n-1]        n<= -1 için y[n] = 0    ve x[n] = d[n]  (d[n] dirac)
# ##### y[0] = x[0] - x[-4] + 1.2y[-1]  = 1
# ##### y[1] = x[1] - x[-3] + 1.2y[0]  = 1.2^1
# ##### y[2] = x[2] - x[-2] + 1.2y[1]  = 1.2^2
# ##### y[3] = x[3] - x[-1] + 1.2y[2]  = 1.2^3
# ##### y[4] = x[4] - x[0] + 1.2y[3]  = 1.2^4 -1 ->1 i yok sayarsak yaklaşık olarak
# ##### y[5] = x[5] - x[1] + 1.2y[4]  = 1.2^5              görüldüğü gibi h[n] = (1.2)^n * u[n]

# %% [markdown]
# ## Soru-2  verilen a ve b giriş işaretlerini verilen sisteme uygulayıp çizdiriniz

# %%
#Kütüphanelerin import edilmesi
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
n = np.arange(-1, 25)
n2 = np.arange(-1, 11)
h1 = np.array([1/3, 1/3, 1/3], dtype = float)

# GİRİŞ SİNYALLERİN TANIMLANMASI
x1 = np.cos(np.pi/5 * n) * np.heaviside(n-10, 1) - np.cos(np.pi/5 * n) * np.heaviside(n-20, 1)
x2 = ((-0.3)**n2) *( np.heaviside(n2-3, 1) - np.heaviside(n2-5, 1))

#ÇIKIŞ SİNYALLERİNİN TANIMLANMASI
y1 = np.convolve(x1, h1, "same")
y2 = np.convolve(x2, h1, "same")

#GRAFIKLERIN ÇİZDİRİLMESİ
plt.figure()
plt.stem(n, x1)
plt.title("x1[n] Giriş Sinyali")
plt.xlabel("Sample Number n")
plt.ylabel("Amplitude")

plt.figure()
plt.stem(y1)
plt.title("y1[n] Çıkış Sinyali")
plt.xlabel("Sample Number n")
plt.ylabel("Amplitude")

plt.figure()
plt.stem(n2, x2)
plt.title("x2[n] Giriş Sinyali")
plt.xlabel("Sample Number n")
plt.ylabel("Amplitude")

plt.figure()
plt.stem(y2)
plt.title("y2[n] Çıkış Sinyali")
plt.xlabel("Sample Number n")
plt.ylabel("Amplitude")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Amplitude')
